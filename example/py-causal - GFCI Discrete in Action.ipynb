# %%
import pandas as pd

# %% [markdown]
# #### Load the example dataset

# %%
data_dir = "https://raw.githubusercontent.com/bd2kccd/py-causal/master/data/audiology.txt"
df = pd.read_table(data_dir, sep="\t")

# %% [markdown]
# #### Start Java VM

# %%
from pycausal.pycausal import pycausal as pc
pc = pc()
pc.start_vm()

# %% [markdown]
# #### Create the Prior Knowledge Object

# %%
from pycausal import prior as p
forbid = [['history_noise','class'],['history_fluctuating','class']]
tempForbid = p.ForbiddenWithin(
    ['class','history_fluctuating','history_noise'])
temporal = [tempForbid]
prior = p.knowledge(forbiddirect = forbid, addtemporal = temporal)
prior
# Out:
# Instance of edu.cmu.tetrad.data.Knowledge2: /knowledge
# addtemporal
#
# 1*  class history_fluctuating history_noise
#
# forbiddirect
#
# requiredirect

# %% [markdown]
# #### Load causal algorithms from the py-causal library and Run GFCI

# %%
from pycausal import search as s
tetrad = s.tetradrunner()
tetrad.listIndTests()
# Out:
# bdeu-test
# cci-test
# cg-lr-test
# chi-square-test
# d-sep-test
# disc-bic-test
# fisher-z-test
# g-square-test
# kci-test
# mnlrlr-test
# mvplr-test
# prob-test

# %%
tetrad.listScores()
# Out:
# bdeu-score
# cci-score
# cg-bic-score
# cg-other-bic-score
# d-sep-score
# disc-bic-score
# disc-mixed-bic-score
# mnlr-bic-score
# mvp-bic-score
# sem-bic-score

# %%
tetrad.getAlgorithmParameters(algoId = 'gfci', testId = 'disc-bic-test', scoreId = 'sem-bic-score')
# Out:
# faithfulnessAssumed: This is a parameter for FGES (“Fast GES”). If this is set to ‘Yes’, it will be assumed that if X _||_ Y, by an independence test, then X _||_ Y | Z for nonempty Z. If the model is faithful to the data, this will necessarily be the case. However, there are some non-faithful examples one can propose where this is not the case. If one is worried about this kind of unfaithfulness, one should set this parameter to ‘No’. If one is willing to tolerate this kind of unfaithfulness, then setting this parameter to ‘Yes’ leads to significantly faster searches. (java.lang.Boolean) [default:true]
# maxDegree: It is possible for a random graph to have a single node with very high degree—i.e. number of adjacent edges. This parameter places an upper bound on the maximum such degree. If no limit is to be placed on the maximum degree, use the value -1. (java.lang.Integer) [default:100]
# ...

# %%
tetrad.run(algoId = 'gfci', dfs = df, testId = 'bdeu-test', scoreId = 'bdeu-score', 
           priorKnowledge = prior, dataType = 'discrete',
           maxDegree = 3, maxPathLength = -1, completeRuleSetUsed = False, 
           faithfulnessAssumed = True, verbose = True)

# %% [markdown]
# #### GFCI Discrete's Result's Nodes

# %%
tetrad.getNodes()
# Out:
# ['age_gt_60',
#  'air',
#  'airBoneGap',
#  'ar_c',
#  'ar_u',
#  'bone',
#  'boneAbnormal',
#  'bser',
#  'history_buzzing',
#  'history_dizziness',
#  'history_fluctuating',
#  'history_fullness',
#  'history_heredity',
#  'history_nausea',
#  'history_noise',
#  'history_recruitment',
#  'history_ringing',
#  'history_roaring',
#  'history_vomiting',
#  'late_wave_poor',
#  'm_at_2k',
#  'm_cond_lt_1k',
#  'm_gt_1k',
#  'm_m_gt_2k',
#  'm_m_sn',
#  'm_m_sn_gt_1k',
#  'm_m_sn_gt_2k',
#  'm_m_sn_gt_500',
#  'm_p_sn_gt_2k',
#  'm_s_gt_500',
#  'm_s_sn',
#  'm_s_sn_gt_1k',
#  'm_s_sn_gt_2k',
#  'm_s_sn_gt_3k',
#  'm_s_sn_gt_4k',
#  'm_sn_2_3k',
#  'm_sn_gt_1k',
#  'm_sn_gt_2k',
#  'm_sn_gt_3k',
#  'm_sn_gt_4k',
#  'm_sn_gt_500',
#  'm_sn_gt_6k',
#  'm_sn_lt_1k',
#  'm_sn_lt_2k',
#  'm_sn_lt_3k',
#  'middle_wave_poor',
#  'mod_gt_4k',
#  'mod_mixed',
#  'mod_s_mixed',
#  'mod_s_sn_gt_500',
#  'mod_sn',
#  'mod_sn_gt_1k',
#  'mod_sn_gt_2k',
#  'mod_sn_gt_3k',
#  'mod_sn_gt_4k',
# ...

# %% [markdown]
# #### GFCI Discrete's Result's Edges

# %%
tetrad.getEdges()
# Out:
# ['m_m_gt_2k --> waveform_ItoV_prolonged',
#  'middle_wave_poor o-o bser',
#  's_sn_gt_4k --> m_m_gt_2k',
#  'm_s_gt_500 --> mod_gt_4k',
#  'mod_sn_gt_1k --> wave_V_delayed',
#  'late_wave_poor o-> m_sn_lt_3k',
#  'history_fullness --> history_buzzing',
#  'mod_gt_4k --> history_heredity',
#  'o_ar_c --> ar_c',
#  'history_roaring --> history_nausea',
#  'wave_V_delayed --> notch_at_4k',
#  'history_fluctuating <-> m_sn_lt_1k',
#  'history_ringing --> m_gt_1k',
#  'm_s_sn --> mod_sn_gt_1k',
#  'middle_wave_poor o-> m_sn_gt_1k',
#  'm_sn_gt_2k o-o late_wave_poor',
#  'm_sn_gt_500 --> history_ringing',
#  'notch_at_4k --> history_noise',
#  'bone --> air',
#  'o_ar_u --> bone',
#  'm_s_sn --> mod_s_sn_gt_500',
#  'm_s_sn_gt_2k --> viith_nerve_signs',
#  'm_sn_gt_500 --> m_m_sn_gt_1k',
#  'm_gt_1k --> m_s_sn_gt_4k',
#  'static_normal --> history_dizziness',
#  'history_roaring --> history_vomiting',
#  'm_s_sn_gt_4k --> mod_sn_gt_500',
#  'history_recruitment o-> m_sn_gt_1k',
# ...

# %% [markdown]
# #### Plot The Result's Graph

# %%
import pydot
from IPython.display import SVG
dot_str = pc.tetradGraphToDot(tetrad.getTetradGraph())
graphs = pydot.graph_from_dot_data(dot_str)
svg_str = graphs[0].create_svg()
SVG(svg_str)

# %% [markdown]
# #### Stop Java VM

# %%
pc.stop_vm()
