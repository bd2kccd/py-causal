# %%
import javabridge
import os
import glob
import pandas as pd
import pydot
from IPython.display import SVG

# %%
tetrad_libdir = os.path.join(os.getcwd(), '../../','src', 'pycausal', 'lib')
for l in glob.glob(tetrad_libdir + os.sep + "*.jar"):
    print (l)
    javabridge.JARS.append(str(l))
# Out:
# /home/jovyan/py-causal/example/javabridge/../../src/pycausal/lib/causal-cmd-1.0.0-jar-with-dependencies.jar

# %%
javabridge.start_vm(run_headless=True, max_heap_size = '100M')
javabridge.attach()

# %%
data_dir = os.path.join(os.getcwd(), '../../','data', 'audiology.txt')
data_dir
# Out:
# '/home/jovyan/py-causal/example/javabridge/../../data/audiology.txt'

# %%
dframe = pd.read_table(data_dir, sep="\t")
dframe.head()
# Out:
#   age_gt_60       air airBoneGap    ar_c    ar_u  bone boneAbnormal bser  \
# 0         f      mild          f  normal  normal     ?            t    ?
# 1         f  moderate          f  normal  normal     ?            t    ?
# 2         t      mild          t       ?  absent  mild            t    ?
# 3         t      mild          t       ?  absent  mild            f    ?
# 4         t      mild          f  normal  normal  mild            t    ?
#
#   history_buzzing  history_dizziness               ...                 \
# 0               f                  f               ...
# 1               f                  f               ...
# 2               f                  f               ...
# 3               f                  f               ...
# 4               f                  f               ...
#
#   s_sn_gt_2k s_sn_gt_4k  speech static_normal tymp viith_nerve_signs  \
# 0          f          f  normal             t    a                 f
# 1          f          f  normal             t    a                 f
# 2          f          f  normal             t   as                 f
# 3          f          f  normal             t    b                 f
# 4          f          f    good             t    a                 f
#
#   wave_V_delayed waveform_ItoV_prolonged indentifier  \
# 0              f                       f          p1
# 1              f                       f          p2
# 2              f                       f          p3
# 3              f                       f          p4
# 4              f                       f          p5
#
#                              class
# 0                 cochlear_unknown
# 1                 cochlear_unknown
# 2      mixed_cochlear_age_fixation
# 3  mixed_cochlear_age_otitis_media
# 4                     cochlear_age
#
# [5 rows x 71 columns]

# %%
dataBox = javabridge.JClassWrapper("edu.cmu.tetrad.data.VerticalIntDataBox")(len(dframe.index),dframe.columns.size)

# %%
node_list = javabridge.JClassWrapper("java.util.ArrayList")()
# load dataset
col_no = 0
for col in dframe.columns:
    
    cat_array = sorted(set(dframe[col]))
    cat_list = javabridge.JClassWrapper("java.util.ArrayList")()

    for cat in cat_array:
        cat = str(cat)
        cat_list.add(cat)
        
    nodi = javabridge.JClassWrapper("edu.cmu.tetrad.data.DiscreteVariable")(col, cat_list)
    node_list.add(nodi)
    
    for row in dframe.index:
        value = javabridge.JClassWrapper("java.lang.Integer") (cat_array.index(dframe.iloc[row,col_no]))
        dataBox.set(row,col_no,value)
    
    col_no = col_no + 1

# %%
boxData = javabridge.JClassWrapper("edu.cmu.tetrad.data.BoxDataSet")(dataBox, node_list)

# %%
score = javabridge.JClassWrapper("edu.cmu.tetrad.search.BDeuScore")(boxData)
score.setStructurePrior(1.0)
score.setSamplePrior(1.0)

# %%
fges = javabridge.JClassWrapper("edu.cmu.tetrad.search.Fges")(score)

# %%
fges.setMaxDegree(-1)
fges.setNumPatternsToStore(0)
fges.setFaithfulnessAssumed(True)
fges.setParallelism(2)
fges.setVerbose(True)

# %%
prior = javabridge.JClassWrapper('edu.cmu.tetrad.data.Knowledge2')()
prior.setForbidden('history_noise','class') # forbidden directed edges
prior.setForbidden('history_fluctuating','class') # forbidden directed edges
prior.setTierForbiddenWithin(0, True)
prior.addToTier(0, 'class')
prior.addToTier(0, 'history_fluctuating')
prior.addToTier(0, 'history_noise')
fges.setKnowledge(prior)
prior
# Out:
# Instance of edu.cmu.tetrad.data.Knowledge2: /knowledge
# addtemporal
#
# 1*  class history_fluctuating history_noise
#
# forbiddirect
#
# requiredirect

# %%
tetradGraph = fges.search()
tetradGraph
# Out:
# Instance of edu.cmu.tetrad.graph.EdgeListGraphSingleConnections: Graph Nodes:
# age_gt_60;air;airBoneGap;ar_c;ar_u;bone;boneAbnormal;bser;history_buzzing;history_dizziness;history_fluctuating;history_fullness;history_heredity;history_nausea;history_noise;history_recruitment;history_ringing;history_roaring;history_vomiting;late_wave_poor;m_at_2k;m_cond_lt_1k;m_gt_1k;m_m_gt_2k;m_m_sn;m_m_sn_gt_1k;m_m_sn_gt_2k;m_m_sn_gt_500;m_p_sn_gt_2k;m_s_gt_500;m_s_sn;m_s_sn_gt_1k;m_s_sn_gt_2k;m_s_sn_gt_3k;m_s_sn_gt_4k;m_sn_2_3k;m_sn_gt_1k;m_sn_gt_2k;m_sn_gt_3k;m_sn_gt_4k;m_sn_gt_500;m_sn_gt_6k;m_sn_lt_1k;m_sn_lt_2k;m_sn_lt_3k;middle_wave_poor;mod_gt_4k;mod_mixed;mod_s_mixed;mod_s_sn_gt_500;mod_sn;mod_sn_gt_1k;mod_sn_gt_2k;mod_sn_gt_3k;mod_sn_gt_4k;mod_sn_gt_500;notch_4k;notch_at_4k;o_ar_c;o_ar_u;s_sn_gt_1k;s_sn_gt_2k;s_sn_gt_4k;speech;static_normal;tymp;viith_nerve_signs;wave_V_delayed;waveform_ItoV_prolonged;indentifier;class
#
# Graph Edges:
# 1. age_gt_60 --- m_m_sn
# 2. airBoneGap --> air
# 3. airBoneGap --- ar_u
# 4. airBoneGap --- tymp
# 5. ar_c --- o_ar_u
# 6. bone --- boneAbnormal
# 7. bser --- middle_wave_poor
# 8. class --- age_gt_60
# 9. class --- notch_at_4k
# 10. class --- tymp
# 11. history_buzzing --- wave_V_delayed
# 12. history_dizziness --> history_fluctuating
# 13. history_dizziness --> history_roaring
# 14. history_dizziness --- static_normal
# 15. history_fluctuating --> history_recruitment
# 16. history_fullness --- history_buzzing
# 17. history_noise --- notch_at_4k
# 18. history_recruitment --> m_sn_gt_1k
# 19. history_roaring --> history_nausea
# 20. history_roaring --> waveform_ItoV_prolonged
# 21. history_vomiting --> history_roaring
# 22. m_sn_lt_1k --> history_fluctuating
# 23. middle_wave_poor --- late_wave_poor
# 24. notch_4k --- m_m_sn_gt_2k
# 25. o_ar_c --- ar_c
# 26. o_ar_c --- ar_u
# 27. o_ar_u --- bone
# 28. s_sn_gt_2k --- history_heredity
# 29. speech --> air
#
# Graph Attributes:
# BIC: -5415.438405
#
# Graph Node Attributes:
# BIC: [age_gt_60: -136.696288;air: -227.283202;airBoneGap: -75.253229;ar_c: -213.103979;ar_u: -208.731205;bone: -289.044335;boneAbnormal: -116.350718;bser: -28.296896;history_buzzing: -10.218322;history_dizziness: -68.901488;history_fluctuating: -34.231635;history_fullness: -10.218322;history_heredity: -15.103646;history_nausea: -49.279775;history_noise: -118.495045;history_recruitment: -15.103646;history_ringing: -23.500993;history_roaring: -40.591650;history_vomiting: -30.838160;late_wave_poor: -15.103646;m_at_2k: -10.218322;m_cond_lt_1k: -1.007212;m_gt_1k: -10.218322;m_m_gt_2k: -15.103646;m_m_sn: -34.231635;m_m_sn_gt_1k: -27.272476;m_m_sn_gt_2k: -19.473094;m_m_sn_gt_500: -10.218322;m_p_sn_gt_2k: -1.007212;m_s_gt_500: -10.218322;m_s_sn: -10.218322;m_s_sn_gt_1k: -1.007212;m_s_sn_gt_2k: -10.218322;m_s_sn_gt_3k: -10.218322;m_s_sn_gt_4k: -10.218322;m_sn_2_3k: -10.218322;m_sn_gt_1k: -37.476828;m_sn_gt_2k: -59.639283;m_sn_gt_3k: -23.500993;m_sn_gt_4k: -40.591650;m_sn_gt_500: -10.218322;m_sn_gt_6k: -1.007212;m_sn_lt_1k: -19.473094;m_sn_lt_2k: -10.218322;m_sn_lt_3k: -10.218322;middle_wave_poor: -15.103646;mod_gt_4k: -10.218322;mod_mixed: -1.007212;mod_s_mixed: -1.007212;mod_s_sn_gt_500: -10.218322;mod_sn: -1.007212;mod_sn_gt_1k: -10.218322;mod_sn_gt_2k: -34.231635;mod_sn_gt_3k: -40.591650;mod_sn_gt_4k: -19.473094;mod_sn_gt_500: -19.473094;notch_4k: -79.238515;notch_at_4k: -46.483024;o_ar_c: -206.090832;o_ar_u: -213.071999;s_sn_gt_1k: -15.103646;s_sn_gt_2k: -30.838160;s_sn_gt_4k: -15.103646;speech: -335.965802;static_normal: -49.279775;tymp: -138.597746;viith_nerve_signs: -10.218322;wave_V_delayed: -15.103646;waveform_ItoV_prolonged: -15.103646;indentifier: -1923.902672;class: -549.673527]

# %%
tetradGraph.toString()
# Out:
# 'Graph Nodes:\nage_gt_60;air;airBoneGap;ar_c;ar_u;bone;boneAbnormal;bser;history_buzzing;history_dizziness;history_fluctuating;history_fullness;history_heredity;history_nausea;history_noise;history_recruitment;history_ringing;history_roaring;history_vomiting;late_wave_poor;m_at_2k;m_cond_lt_1k;m_gt_1k;m_m_gt_2k;m_m_sn;m_m_sn_gt_1k;m_m_sn_gt_2k;m_m_sn_gt_500;m_p_sn_gt_2k;m_s_gt_500;m_s_sn;m_s_sn_gt_1k;m_s_sn_gt_2k;m_s_sn_gt_3k;m_s_sn_gt_4k;m_sn_2_3k;m_sn_gt_1k;m_sn_gt_2k;m_sn_gt_3k;m_sn_gt_4k;m_sn_gt_500;m_sn_gt_6k;m_sn_lt_1k;m_sn_lt_2k;m_sn_lt_3k;middle_wave_poor;mod_gt_4k;mod_mixed;mod_s_mixed;mod_s_sn_gt_500;mod_sn;mod_sn_gt_1k;mod_sn_gt_2k;mod_sn_gt_3k;mod_sn_gt_4k;mod_sn_gt_500;notch_4k;notch_at_4k;o_ar_c;o_ar_u;s_sn_gt_1k;s_sn_gt_2k;s_sn_gt_4k;speech;static_normal;tymp;viith_nerve_signs;wave_V_delayed;waveform_ItoV_prolonged;indentifier;class\n\nGraph Edges:\n1. age_gt_60 --- m_m_sn\n2. airBoneGap --> air\n3. airBoneGap --- ar_u\n4. airBoneGap --- tymp\n5. ar_c --- o_ar_u\n6. bone --- boneAbnormal\n7. bser --- middle_wave_poor\n8. class --- age_gt_60\n9. class --- notch_at_4k\n10. class --- tymp\n11. history_buzzing --- wave_V_delayed\n12. history_dizziness --> history_fluctuating\n13. history_dizziness --> history_roaring\n14. history_dizziness --- static_normal\n15. history_fluctuating --> history_recruitment\n16. history_fullness --- history_buzzing\n17. history_noise --- notch_at_4k\n18. history_recruitment --> m_sn_gt_1k\n19. history_roaring --> history_nausea\n20. history_roaring --> waveform_ItoV_prolonged\n21. history_vomiting --> history_roaring\n22. m_sn_lt_1k --> history_fluctuating\n23. middle_wave_poor --- late_wave_poor\n24. notch_4k --- m_m_sn_gt_2k\n25. o_ar_c --- ar_c\n26. o_ar_c --- ar_u\n27. o_ar_u --- bone\n28. s_sn_gt_2k --- history_heredity\n29. speech --> air\n\nGraph Attributes:\nBIC: -5415.438405\n\nGraph Node Attributes:\nBIC: [age_gt_60: -136.696288;air: -227.283202;airBoneGap: -75.253229;ar_c: -213.103979;ar_u: -208.731205;bone: -289.044335;boneAbnormal: -116.350718;bser: -28.296896;history_buzzing: -10.218322;history_dizziness: -68.901488;history_fluctuating: -34.231635;history_fullness: -10.218322;history_heredity: -15.103646;history_nausea: -49.279775;history_noise: -118.495045;history_recruitment: -15.103646;history_ringing: -23.500993;history_roaring: -40.591650;history_vomiting: -30.838160;late_wave_poor: -15.103646;m_at_2k: -10.218322;m_cond_lt_1k: -1.007212;m_gt_1k: -10.218322;m_m_gt_2k: -15.103646;m_m_sn: -34.231635;m_m_sn_gt_1k: -27.272476;m_m_sn_gt_2k: -19.473094;m_m_sn_gt_500: -10.218322;m_p_sn_gt_2k: -1.007212;m_s_gt_500: -10.218322;m_s_sn: -10.218322;m_s_sn_gt_1k: -1.007212;m_s_sn_gt_2k: -10.218322;m_s_sn_gt_3k: -10.218322;m_s_sn_gt_4k: -10.218322;m_sn_2_3k: -10.218322;m_sn_gt_1k: -37.476828;m_sn_gt_2k: -59.639283;m_sn_gt_3k: -23.500993;m_sn_gt_4k: -40.591650;m_sn_gt_500: -10.218322;m_sn_gt_6k: -1.007212;m_sn_lt_1k: -19.473094;m_sn_lt_2k: -10.218322;m_sn_lt_3k: -10.218322;middle_wave_poor: -15.103646;mod_gt_4k: -10.218322;mod_mixed: -1.007212;mod_s_mixed: -1.007212;mod_s_sn_gt_500: -10.218322;mod_sn: -1.007212;mod_sn_gt_1k: -10.218322;mod_sn_gt_2k: -34.231635;mod_sn_gt_3k: -40.591650;mod_sn_gt_4k: -19.473094;mod_sn_gt_500: -19.473094;notch_4k: -79.238515;notch_at_4k: -46.483024;o_ar_c: -206.090832;o_ar_u: -213.071999;s_sn_gt_1k: -15.103646;s_sn_gt_2k: -30.838160;s_sn_gt_4k: -15.103646;speech: -335.965802;static_normal: -49.279775;tymp: -138.597746;viith_nerve_signs: -10.218322;wave_V_delayed: -15.103646;waveform_ItoV_prolonged: -15.103646;indentifier: -1923.902672;class: -549.673527]\n'

# %%
tetradGraph.getNodeNames()
# Out:
# Instance of java.util.ArrayList: [age_gt_60, air, airBoneGap, ar_c, ar_u, bone, boneAbnormal, bser, history_buzzing, history_dizziness, history_fluctuating, history_fullness, history_heredity, history_nausea, history_noise, history_recruitment, history_ringing, history_roaring, history_vomiting, late_wave_poor, m_at_2k, m_cond_lt_1k, m_gt_1k, m_m_gt_2k, m_m_sn, m_m_sn_gt_1k, m_m_sn_gt_2k, m_m_sn_gt_500, m_p_sn_gt_2k, m_s_gt_500, m_s_sn, m_s_sn_gt_1k, m_s_sn_gt_2k, m_s_sn_gt_3k, m_s_sn_gt_4k, m_sn_2_3k, m_sn_gt_1k, m_sn_gt_2k, m_sn_gt_3k, m_sn_gt_4k, m_sn_gt_500, m_sn_gt_6k, m_sn_lt_1k, m_sn_lt_2k, m_sn_lt_3k, middle_wave_poor, mod_gt_4k, mod_mixed, mod_s_mixed, mod_s_sn_gt_500, mod_sn, mod_sn_gt_1k, mod_sn_gt_2k, mod_sn_gt_3k, mod_sn_gt_4k, mod_sn_gt_500, notch_4k, notch_at_4k, o_ar_c, o_ar_u, s_sn_gt_1k, s_sn_gt_2k, s_sn_gt_4k, speech, static_normal, tymp, viith_nerve_signs, wave_V_delayed, waveform_ItoV_prolonged, indentifier, class]

# %%
tetradGraph.getEdges()
# Out:
# Instance of java.util.HashSet: [class --- tymp, airBoneGap --- ar_u, history_roaring --> history_nausea, history_noise --- notch_at_4k, history_fullness --- history_buzzing, s_sn_gt_2k --- history_heredity, history_dizziness --- static_normal, speech --> air, airBoneGap --- tymp, class --- notch_at_4k, history_fluctuating --> history_recruitment, o_ar_c --- ar_c, history_buzzing --- wave_V_delayed, history_roaring --> waveform_ItoV_prolonged, age_gt_60 --- m_m_sn, ar_c --- o_ar_u, history_vomiting --> history_roaring, notch_4k --- m_m_sn_gt_2k, airBoneGap --> air, history_dizziness --> history_roaring, m_sn_lt_1k --> history_fluctuating, class --- age_gt_60, history_dizziness --> history_fluctuating, bser --- middle_wave_poor, o_ar_u --- bone, o_ar_c --- ar_u, middle_wave_poor --- late_wave_poor, bone --- boneAbnormal, history_recruitment --> m_sn_gt_1k]

# %%
dot_str = javabridge.static_call('edu/cmu/tetrad/graph/GraphUtils',
                                   'graphToDot',
                                   '(Ledu/cmu/tetrad/graph/Graph;)Ljava/lang/String;', 
                                   tetradGraph)
graphs = pydot.graph_from_dot_data(dot_str)
svg_str = graphs[0].create_svg()
SVG(svg_str)

# %%
javabridge.detach()
javabridge.kill_vm()
